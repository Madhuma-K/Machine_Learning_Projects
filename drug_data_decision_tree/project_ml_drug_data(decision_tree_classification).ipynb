# %% [markdown]
# # DRUG TYPE PREDICTION USING MACHINE LEARNING CLASSIFICATION MODELS

# %% [markdown]
# This project aim to classify the appropriate drug type for patients based on their health parameters using a variety of machine learning classification models. The dataset includes features such as age, gender, blood pressure (BP), cholesterol levels, and the sodium-to-potassium ratio (Na_to_K), with the target variable being the prescribed drug category. By implementing models such as K-Nearest Neighbors (KNN),Random Forest, Decision Tree, and Logistic Regression, this project seeks to compare model performance and determine the most effective approach for accurate drug prediction.

# %% [markdown]
# Importing Dataset and libraries

# %%
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
df=pd.read_csv(r"E:\data_analytics\ml_works\machine_learning_projects\drug200.csv")
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %% [markdown]
# Information About Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %% [markdown]
# Encoding Categorical data

# %%
le=LabelEncoder()
column_to_convert=['BP','Cholesterol','Drug']
for col in column_to_convert:
    df[col]=le.fit_transform(df[col])
df.head(10)
# Out:
#    Age Sex  BP  Cholesterol  Na_to_K  Drug
# 0   23   F   0            0   25.355     0
# 1   47   M   1            0   13.093     3
# 2   47   M   1            0   10.114     3
# 3   28   F   2            0    7.798     4
# 4   61   F   1            0   18.043     0
# 5   22   F   2            0    8.607     4
# 6   49   F   2            0   16.275     0
# 7   41   M   1            0   11.037     3
# 8   60   M   2            0   15.171     0
# 9   43   M   1            1   19.368     0

# %% [markdown]
# Independent and Dependent Variable

# %%
x=df.iloc[:,[0,2,3,4]].values
x=pd.DataFrame(x)
y=df.iloc[:,5].values
y=pd.DataFrame(y)
print(x)
print(y)
# Out:
#         0    1    2       3
# 0    23.0  0.0  0.0  25.355
# 1    47.0  1.0  0.0  13.093
# 2    47.0  1.0  0.0  10.114
# 3    28.0  2.0  0.0   7.798
# 4    61.0  1.0  0.0  18.043
# ..    ...  ...  ...     ...
# 195  56.0  1.0  0.0  11.567
# 196  16.0  1.0  0.0  12.006
# 197  52.0  2.0  0.0   9.894
# 198  23.0  2.0  1.0  14.020
# 199  40.0  1.0  1.0  11.349
#
# [200 rows x 4 columns]
#      0
# 0    0
# 1    3
# 2    3
# 3    4
# 4    0
# ..  ..
# 195  3
# 196  3
# 197  4
# 198  4
# 199  4
#
# [200 rows x 1 columns]

# %% [markdown]
# Splitting Variable to test and train

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %% [markdown]
# Feature Scaling

# %%
st_x=StandardScaler()
x_train=st_x.fit_transform(x_train)
x_test=st_x.fit_transform(x_test)
print(x_train)
# Out:
# [[-1.56623476  1.29344713  1.09812675 -0.95102405]
#  [-0.27267433  0.10315836  1.09812675  0.36126848]
#  [-1.44303853  1.29344713 -0.91064169 -1.0445412 ]
#  [ 1.26727857 -1.08713041 -0.91064169  0.02937974]
#  [-0.33427244  1.29344713 -0.91064169 -0.83697198]
#  [-0.27267433  1.29344713  1.09812675  0.93929879]
#  [ 0.2201106  -1.08713041  1.09812675 -1.36893747]
#  [-1.56623476 -1.08713041  1.09812675  2.7061346 ]
#  [-0.39587056  1.29344713  1.09812675  0.15120178]
#  [ 0.77449364  0.10315836 -0.91064169  3.06799323]
#  [-1.56623476 -1.08713041 -0.91064169 -0.67616134]
#  [ 0.65129741 -1.08713041 -0.91064169  1.28478499]
#  [ 1.76006349 -1.08713041 -0.91064169 -0.9113417 ]
#  [-0.14947809  0.10315836 -0.91064169 -0.105346  ]
#  [ 0.03531625  1.29344713  1.09812675 -1.227968  ]
#  [ 0.95928799 -1.08713041 -0.91064169  1.29588494]
#  [ 0.28170872  1.29344713  1.09812675 -0.04790372]
#  [ 1.14408234 -1.08713041  1.09812675  0.66554608]
#  [ 1.02088611  1.29344713 -0.91064169  0.06365086]
#  [ 0.5896993  -1.08713041 -0.91064169 -0.71570494]
#  [ 1.32887668  1.29344713  1.09812675 -0.72666615]
#  [-0.64226302  1.29344713  1.09812675 -1.15026829]
#  [-0.14947809  1.29344713  1.09812675 -0.45457843]
#  [ 0.77449364 -1.08713041  1.09812675 -0.26310415]
#  [-0.82705737 -1.08713041  1.09812675 -0.81074833]
#  [ 1.20568045  0.10315836  1.09812675 -0.32831641]
#  [-0.88865548 -1.08713041 -0.91064169  1.97450862]
#  [ 1.45207292  1.29344713 -0.91064169 -0.84224446]
#  [-0.88865548 -1.08713041  1.09812675 -0.59166291]
#  [ 0.09691437  1.29344713  1.09812675 -1.31149518]
#  [ 0.09691437  0.10315836 -0.91064169 -0.83544574]
#  [-1.19664606 -1.08713041  1.09812675  0.41982076]
#  [-0.51906679 -1.08713041 -0.91064169 -0.42238855]
#  [ 0.09691437 -1.08713041 -0.91064169 -0.79534714]
#  [-1.38144041 -1.08713041 -0.91064169 -1.12723588]
#  [ 0.83609176 -1.08713041 -0.91064169 -0.30528399]
#  [ 0.71289553 -1.08713041  1.09812675 -0.8588944 ]
#  [-0.82705737 -1.08713041  1.09812675 -0.92826914]
#  [ 0.77449364 -1.08713041 -0.91064169  0.39623335]
#  [-1.31984229 -1.08713041  1.09812675 -0.92410665]
#  [ 0.09691437  0.10315836  1.09812675  2.00253602]
#  [ 1.14408234  0.10315836  1.09812675  1.3327923 ]
#  [-0.02628186 -1.08713041 -0.91064169 -0.45527218]
#  [ 1.20568045 -1.08713041  1.09812675  2.18402033]
#  [-0.70386114 -1.08713041  1.09812675  0.42509324]
#  [ 0.03531625 -1.08713041 -0.91064169  2.57390635]
#  [-0.70386114  0.10315836  1.09812675 -0.44569846]
#  [ 0.2201106   1.29344713 -0.91064169  0.01938978]
#  [ 0.2201106   1.29344713  1.09812675 -0.9371491 ]
#  [-1.07344983  1.29344713 -0.91064169  1.51635786]
#  [ 0.95928799  0.10315836 -0.91064169  0.26469885]
#  [ 0.2201106   0.10315836  1.09812675 -0.71057121]
#  [ 0.89768987 -1.08713041  1.09812675 -1.0425987 ]
#  [ 0.95928799  1.29344713 -0.91064169 -0.92854663]
#  [-1.38144041  1.29344713 -0.91064169  0.09917072]
#  [-0.39587056 -1.08713041 -0.91064169 -0.897883  ]
#  [ 0.09691437  0.10315836 -0.91064169 -0.60609286]
#  [ 1.32887668  0.10315836  1.09812675  0.63238496]
#  [-0.64226302  0.10315836  1.09812675 -0.96642524]
#  [-0.51906679  0.10315836  1.09812675 -0.57293173]
#  [ 0.77449364  0.10315836 -0.91064169  1.45822183]
#  [-1.38144041 -1.08713041 -0.91064169  1.27923501]
#  [-1.38144041  1.29344713  1.09812675 -0.29349029]
#  [ 1.63686726  0.10315836  1.09812675 -0.20718812]
#  [ 1.51367103 -1.08713041 -0.91064169 -0.30084401]
#  [-0.5806649   1.29344713 -0.91064169  0.08571203]
#  [ 0.89768987 -1.08713041 -0.91064169 -0.39297366]
#  [ 0.28170872  1.29344713  1.09812675 -0.53283313]
#  [-1.50463664 -1.08713041  1.09812675  1.73391704]
#  [-0.39587056  0.10315836  1.09812675  0.9104389 ]
#  [ 1.69846538  1.29344713 -0.91064169  0.42814573]
#  [ 1.63686726 -1.08713041  1.09812675 -0.89607926]
#  [ 0.2201106   0.10315836 -0.91064169 -0.77675471]
#  [-0.88865548 -1.08713041  1.09812675 -0.68101757]
#  [-1.07344983 -1.08713041  1.09812675  0.37098095]
#  [ 0.15851248  0.10315836 -0.91064169 -0.15252082]
#  [-1.68943099 -1.08713041 -0.91064169  2.92105754]
#  [-1.19664606 -1.08713041  1.09812675 -0.53116814]
#  [ 1.14408234  1.29344713 -0.91064169 -1.16192325]
#  [-1.87422534  1.29344713 -0.91064169 -0.9783577 ]
#  [ 0.34330683  0.10315836  1.09812675  0.95289624]
#  [ 1.3904748   0.10315836 -0.91064169 -0.81088708]
#  [ 0.65129741  0.10315836 -0.91064169 -0.15543456]
#  [-0.51906679  0.10315836  1.09812675  0.08168829]
#  [-1.38144041  1.29344713 -0.91064169 -0.53768936]
#  [ 0.34330683 -1.08713041  1.09812675 -0.66492263]
#  [-1.07344983  1.29344713 -0.91064169 -1.15678952]
#  [-0.51906679  0.10315836  1.09812675 -0.99445263]
#  [-1.31984229 -1.08713041  1.09812675  0.32214113]
#  [-1.31984229  1.29344713 -0.91064169  1.33903603]
#  [-1.44303853 -1.08713041  1.09812675  0.92722759]
#  [-0.39587056  1.29344713 -0.91064169 -0.02306756]
#  [ 0.71289553  1.29344713  1.09812675  1.35388222]
#  [-1.07344983  0.10315836 -0.91064169  0.50792668]
#  [ 0.89768987 -1.08713041 -0.91064169 -0.30542274]
#  [ 0.46650306  1.29344713 -0.91064169 -0.2778116 ]
#  [-0.27267433  0.10315836 -0.91064169 -0.70737997]
#  [ 0.28170872 -1.08713041 -0.91064169 -1.19952436]
#  [-0.27267433 -1.08713041  1.09812675 -0.13587089]
#  [-0.45746867 -1.08713041  1.09812675 -0.66728137]
#  [ 0.15851248 -1.08713041  1.09812675 -0.78938091]
#  [ 0.83609176  1.29344713 -0.91064169 -0.31236022]
#  [ 0.28170872  1.29344713  1.09812675  0.14925928]
#  [ 0.89768987  1.29344713 -0.91064169 -0.13378964]
#  [ 1.76006349  0.10315836 -0.91064169  0.66693357]
#  [-0.70386114 -1.08713041 -0.91064169  0.3562735 ]
#  [-0.02628186  0.10315836  1.09812675 -0.84890444]
#  [ 0.40490495  0.10315836  1.09812675  2.32915228]
#  [-0.14947809 -1.08713041 -0.91064169 -0.30015026]
#  [-1.31984229  1.29344713 -0.91064169 -0.76731974]
#  [ 1.69846538 -1.08713041 -0.91064169  0.30701744]
#  [-0.21107621 -1.08713041 -0.91064169  0.67997603]
#  [ 0.71289553  1.29344713 -0.91064169 -0.26629539]
#  [-0.5806649  -1.08713041  1.09812675 -0.08952856]
#  [-0.02628186  0.10315836  1.09812675 -1.07742482]
#  [ 1.3904748  -1.08713041  1.09812675 -0.82503953]
#  [-0.21107621  0.10315836 -0.91064169  0.53803531]
#  [ 0.77449364 -1.08713041 -0.91064169  0.45520188]
#  [-1.81262722  0.10315836 -0.91064169 -0.57293173]
#  [ 0.89768987  1.29344713  1.09812675 -0.83863697]
#  [-1.38144041  1.29344713 -0.91064169  2.15765793]
#  [-0.51906679 -1.08713041  1.09812675  0.9651062 ]
#  [ 1.08248422  1.29344713 -0.91064169  1.35721221]
#  [-0.33427244 -1.08713041 -0.91064169  1.62208496]
#  [-0.9502536   1.29344713 -0.91064169 -0.78979716]
#  [ 1.63686726  0.10315836 -0.91064169  0.02424601]
#  [-0.82705737  1.29344713 -0.91064169 -1.2013281 ]
#  [-0.39587056  0.10315836  1.09812675 -0.30486775]
#  [ 0.46650306  0.10315836 -0.91064169  0.94734626]
#  [ 1.63686726  0.10315836 -0.91064169 -1.29956273]
#  [ 0.09691437  0.10315836 -0.91064169 -0.42211105]
#  [ 1.02088611  0.10315836  1.09812675  1.53286905]
#  [-1.44303853  0.10315836 -0.91064169 -1.10781096]
#  [ 1.51367103  1.29344713 -0.91064169  0.60408006]
#  [ 1.3904748  -1.08713041 -0.91064169 -0.71126496]
#  [ 0.65129741  1.29344713 -0.91064169 -0.99473013]
#  [-1.87422534 -1.08713041  1.09812675  0.08182704]
#  [ 1.32887668  1.29344713  1.09812675 -0.91869542]
#  [ 1.45207292  0.10315836 -0.91064169 -0.09119355]
#  [-0.88865548 -1.08713041  1.09812675  0.12955686]
#  [-1.87422534 -1.08713041  1.09812675  0.14856554]
#  [-0.33427244  0.10315836  1.09812675 -0.66409014]
#  [ 0.71289553  0.10315836  1.09812675  0.41524203]
#  [ 1.20568045 -1.08713041  1.09812675  2.61705744]
#  [-1.07344983  1.29344713 -0.91064169  0.49113799]
#  [-1.44303853  1.29344713 -0.91064169 -0.58028545]
#  [ 0.28170872  1.29344713 -0.91064169 -0.47622335]
#  [-1.01185172 -1.08713041 -0.91064169  1.84741411]
#  [ 1.32887668  1.29344713 -0.91064169 -0.03389002]
#  [-1.07344983  0.10315836 -0.91064169 -0.41739357]]

# %% [markdown]
# ### Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Model fitting

# %%
classifier=DecisionTreeClassifier(criterion='entropy',random_state=42)
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %% [markdown]
# Model Prediction

# %%
y_pred=classifier.predict(x_test)
print(y_pred)
print(y_test)
# Out:
# [4 0 4 3 0 0 0 4 1 4 1 4 0 1 2 0 2 4 3 0 2 4 4 0 0 0 3 4 0 4 0 3 3 0 2 0 4
#  1 0 1 4 4 4 0 0 3 0 0 0 4]
#      0
# 95   4
# 15   0
# 30   4
# 158  3
# 128  0
# 115  0
# 69   0
# 170  4
# 174  1
# 45   4
# 66   1
# 182  4
# 165  0
# 78   1
# 186  2
# 177  0
# 56   2
# 152  4
# 82   3
# 68   0
# 124  2
# 16   4
# 148  4
# 93   0
# 65   0
# 60   0
# 84   3
# 67   4
# 125  0
# 132  4
# 9    0
# 18   3
# 55   3
# 75   0
# 150  1
# 104  0
# 135  4
# 137  1
# 164  0
# 76   1
# 79   4
# 197  4
# 38   4
# 24   0
# 122  0
# 195  3
# 29   0
# 19   0
# 143  0
# 86   4

# %% [markdown]
# Model Evaluation

# %%
print("mean absolute error:",metrics.mean_absolute_error(y_test,y_pred))
print("mean squared error:",metrics.mean_squared_error(y_test,y_pred))
print("root mean squared error:",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# mean absolute error: 0.02
# mean squared error: 0.02
# root mean squared error: 0.1414213562373095

# %% [markdown]
# Prediction Accuracy

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)
print(accuracy*100,"%")
# Out:
# 98.0 %

# %% [markdown]
# ### SVM Model

# %%
from sklearn.svm import SVC

# %% [markdown]
# Model Fitting

# %%
classifier=SVC(kernel='linear',random_state=42)
classifier.fit(x_train,y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %% [markdown]
# Model Prediction

# %%
y_pred=classifier.predict(x_test)
print(y_pred)
print(y_test)
# Out:
# [4 0 4 3 0 0 0 4 1 4 1 4 0 1 2 0 2 4 3 0 2 4 4 0 0 0 3 4 0 4 0 3 3 0 2 0 4
#  1 0 1 4 4 4 0 0 3 0 0 2 4]
#      0
# 95   4
# 15   0
# 30   4
# 158  3
# 128  0
# 115  0
# 69   0
# 170  4
# 174  1
# 45   4
# 66   1
# 182  4
# 165  0
# 78   1
# 186  2
# 177  0
# 56   2
# 152  4
# 82   3
# 68   0
# 124  2
# 16   4
# 148  4
# 93   0
# 65   0
# 60   0
# 84   3
# 67   4
# 125  0
# 132  4
# 9    0
# 18   3
# 55   3
# 75   0
# 150  1
# 104  0
# 135  4
# 137  1
# 164  0
# 76   1
# 79   4
# 197  4
# 38   4
# 24   0
# 122  0
# 195  3
# 29   0
# 19   0
# 143  0
# 86   4

# %% [markdown]
# Model Evaluation

# %%
print("mean absolute error:",metrics.mean_absolute_error(y_test,y_pred))
print("mean squared error:",metrics.mean_squared_error(y_test,y_pred))
print("root mean squared error:",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# mean absolute error: 0.06
# mean squared error: 0.1
# root mean squared error: 0.31622776601683794

# %% [markdown]
# Prediction Accuracy

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)
print(accuracy*100,"%")
# Out:
# 96.0 %

# %% [markdown]
# ### KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Model Fitting

# %%
classifier=KNeighborsClassifier(n_neighbors=5,metric='minkowski',p=2)
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Model Prediction

# %%
y_pred=classifier.predict(x_test)
print(y_pred)
print(y_test)
# Out:
# [4 0 4 3 0 0 0 4 0 4 1 4 0 1 2 0 2 4 3 0 2 4 4 0 0 0 3 4 0 4 0 3 3 0 2 0 4
#  1 0 1 4 4 4 0 0 3 0 0 2 4]
#      0
# 95   4
# 15   0
# 30   4
# 158  3
# 128  0
# 115  0
# 69   0
# 170  4
# 174  1
# 45   4
# 66   1
# 182  4
# 165  0
# 78   1
# 186  2
# 177  0
# 56   2
# 152  4
# 82   3
# 68   0
# 124  2
# 16   4
# 148  4
# 93   0
# 65   0
# 60   0
# 84   3
# 67   4
# 125  0
# 132  4
# 9    0
# 18   3
# 55   3
# 75   0
# 150  1
# 104  0
# 135  4
# 137  1
# 164  0
# 76   1
# 79   4
# 197  4
# 38   4
# 24   0
# 122  0
# 195  3
# 29   0
# 19   0
# 143  0
# 86   4

# %% [markdown]
# Model Evaluation

# %%
print("mean absolute error:",metrics.mean_absolute_error(y_test,y_pred))
print("mean squared error:",metrics.mean_squared_error(y_test,y_pred))
print("root mean squared error:",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# mean absolute error: 0.08
# mean squared error: 0.12
# root mean squared error: 0.34641016151377546

# %% [markdown]
# Prediction Accuracy

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)
print(accuracy*100,"%")
# Out:
# 94.0 %

# %% [markdown]
# ### Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# Model Fitting

# %%
classifier=RandomForestClassifier(criterion='entropy',n_estimators=10,random_state=42)
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=42)

# %% [markdown]
# Model Prediction

# %%
y_pred=classifier.predict(x_test)
print(y_test)
print(y_pred)
# Out:
#      0
# 95   4
# 15   0
# 30   4
# 158  3
# 128  0
# 115  0
# 69   0
# 170  4
# 174  1
# 45   4
# 66   1
# 182  4
# 165  0
# 78   1
# 186  2
# 177  0
# 56   2
# 152  4
# 82   3
# 68   0
# 124  2
# 16   4
# 148  4
# 93   0
# 65   0
# 60   0
# 84   3
# 67   4
# 125  0
# 132  4
# 9    0
# 18   3
# 55   3
# 75   0
# 150  1
# 104  0
# 135  4
# 137  1
# 164  0
# 76   1
# 79   4
# 197  4
# 38   4
# 24   0
# 122  0
# 195  3
# 29   0
# 19   0
# 143  0
# 86   4
# [4 0 4 3 0 0 0 4 1 4 1 4 0 1 2 0 2 4 3 0 2 4 4 0 0 0 3 4 0 4 0 3 4 0 2 0 4
#  1 0 1 4 4 4 0 0 3 0 0 0 4]

# %% [markdown]
# Model Evaluation

# %%
print("mean absolute error:",metrics.mean_absolute_error(y_test,y_pred))
print("mean squared error:",metrics.mean_squared_error(y_test,y_pred))
print("root mean squared error:",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# mean absolute error: 0.04
# mean squared error: 0.04
# root mean squared error: 0.2

# %% [markdown]
# Prediction Accuracy

# %%
accuracy=metrics.accuracy_score(y_test,y_pred)
print(accuracy*100,"%")
# Out:
# 96.0 %

# %% [markdown]
# ### Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Model Fitting

# %%
model=LogisticRegression(max_iter=1000)
model.fit(x_test,y_test)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# Model Prediction

# %%
y_pred=model.predict(x_test)
print(y_test)
print(y_pred)
# Out:
#      0
# 95   4
# 15   0
# 30   4
# 158  3
# 128  0
# 115  0
# 69   0
# 170  4
# 174  1
# 45   4
# 66   1
# 182  4
# 165  0
# 78   1
# 186  2
# 177  0
# 56   2
# 152  4
# 82   3
# 68   0
# 124  2
# 16   4
# 148  4
# 93   0
# 65   0
# 60   0
# 84   3
# 67   4
# 125  0
# 132  4
# 9    0
# 18   3
# 55   3
# 75   0
# 150  1
# 104  0
# 135  4
# 137  1
# 164  0
# 76   1
# 79   4
# 197  4
# 38   4
# 24   0
# 122  0
# 195  3
# 29   0
# 19   0
# 143  0
# 86   4
# [4 0 4 3 0 0 0 4 1 4 1 4 0 1 2 0 2 4 3 0 1 4 4 0 0 0 3 4 0 4 0 3 3 0 1 0 4
#  1 0 1 4 4 4 0 0 3 0 0 2 4]

# %% [markdown]
# Model Evaluation

# %%
print("mean absolute error:",metrics.mean_absolute_error(y_test,y_pred))
print("mean squared error:",metrics.mean_squared_error(y_test,y_pred))
print("root mean squared error:",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# mean absolute error: 0.06
# mean squared error: 0.1
# root mean squared error: 0.31622776601683794

# %% [markdown]
# Prediction Accuracy

# %%
score=metrics.accuracy_score(y_test,y_pred)
print(score*100,"%")
# Out:
# 96.0 %

# %% [markdown]
# Conclusion:
# The classification project aimed to predict the appropriate drug type for patients using various machine learning models, including KNN,SVM,Random Forest, Decision Tree, and Logistic Regression. The Decision Tree model emerged as the best performer, achieving an impressive accuracy of 98%. This high accuracy indicates that the model effectively captured the relationships between patient health parameters and the prescribed drug type.
